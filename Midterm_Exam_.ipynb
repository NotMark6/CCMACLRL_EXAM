# %% [markdown]
# <a href="https://colab.research.google.com/github/NotMark6/CCMACLRL_EXAM/blob/main/Midterm_Exam_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from datetime import datetime
import re

# %% [markdown]
# ## Dataset File

# %%
dataset_url = 'https://github.com/robitussin/CCMACLRL_EXAM/blob/a46a4e2a001dedaefc9b431d480b508ce86c2d96/datasets/train.csv?raw=true'
df = pd.read_csv(dataset_url)

# %%
df.head()
# Out:
#    id          brand              model  model_year  milage      fuel_type  \
# 0   0           MINI      Cooper S Base        2007  213000       Gasoline
# 1   1        Lincoln              LS V8        2002  143250       Gasoline
# 2   2      Chevrolet  Silverado 2500 LT        2002  136731  E85 Flex Fuel
# 3   3        Genesis   G90 5.0 Ultimate        2017   19500       Gasoline
# 4   4  Mercedes-Benz        Metris Base        2021    7388       Gasoline
#
#                                               engine  \
# 0       172.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# 1       252.0HP 3.9L 8 Cylinder Engine Gasoline Fuel
# 2  320.0HP 5.3L 8 Cylinder Engine Flex Fuel Capab...
# 3       420.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 4       208.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
#
#                      transmission ext_col int_col  \
# 0                             A/T  Yellow    Gray
# 1                             A/T  Silver   Beige
# 2                             A/T    Blue    Gray
# 3  Transmission w/Dual Shift Mode   Black   Black
# 4                     7-Speed A/T   Black   Beige
#
#                                  accident clean_title  price
# 0                           None reported         Yes   4200
# 1  At least 1 accident or damage reported         Yes   4999
# 2                           None reported         Yes  13900
# 3                           None reported         Yes  45000
# 4                           None reported         Yes  97500

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188533 entries, 0 to 188532
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            188533 non-null  int64
#  1   brand         188533 non-null  object
#  2   model         188533 non-null  object
#  3   model_year    188533 non-null  int64
#  4   milage        188533 non-null  int64
#  5   fuel_type     183450 non-null  object
#  6   engine        188533 non-null  object
#  7   transmission  188533 non-null  object
#  8   ext_col       188533 non-null  object
#  9   int_col       188533 non-null  object
#  10  accident      186081 non-null  object
#  11  clean_title   167114 non-null  object
#  12  price         188533 non-null  int64
# dtypes: int64(4), object(9)
# memory usage: 18.7+ MB

# %%
df.isnull().sum()
# Out:
# id                  0
# brand               0
# model               0
# model_year          0
# milage              0
# fuel_type        5083
# engine              0
# transmission        0
# ext_col             0
# int_col             0
# accident         2452
# clean_title     21419
# price               0
# dtype: int64

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# id              0
# brand           0
# model           0
# model_year      0
# milage          0
# fuel_type       0
# engine          0
# transmission    0
# ext_col         0
# int_col         0
# accident        0
# clean_title     0
# price           0
# dtype: int64

# %%
df.describe()
# Out:
#                   id     model_year         milage         price
# count  162610.000000  162610.000000  162610.000000  1.626100e+05
# mean    94197.039137    2015.158822   71105.487086  4.081699e+04
# std     54467.770815       5.699531   50157.874111  7.653857e+04
# min         0.000000    1974.000000     100.000000  2.000000e+03
# 25%     47026.250000    2012.000000   29000.000000  1.570000e+04
# 50%     94139.000000    2016.000000   64300.000000  2.850000e+04
# 75%    141421.750000    2019.000000  101000.000000  4.699900e+04
# max    188532.000000    2024.000000  405000.000000  2.954083e+06

# %%
df.sample(20)
# Out:
#             id          brand                             model  model_year  \
# 33636    33636           Ford                        Taurus SHO        2016
# 86166    86166  Mercedes-Benz                 GLK-Class GLK 350        2015
# 111314  111314     Volkswagen           Golf GTI 2.0T SE 4-Door        2015
# 168952  168952         Toyota                    Highlander XLE        2015
# 149629  149629           Ford                Mustang GT Premium        2018
# 68511    68511           Jeep                  Liberty Renegade        2007
# 134137  134137        Porsche                           911 GT3        2022
# 31629    31629            GMC                      Acadia SLT-1        2020
# 3548      3548            BMW                      750 i xDrive        2015
# 90029    90029           MINI                       Cooper Base        2016
# 96554    96554        Lincoln                 Navigator Reserve        2019
# 76525    76525  Mercedes-Benz                       Metris Base        2021
# 85813    85813          Mazda              Mazda3 Grand Touring        2021
# 148858  148858  Mercedes-Benz              E-Class E 350 4MATIC        2008
# 182435  182435      Chevrolet                     Corvette Base        2010
# 188432  188432           Ford                         F-150 XLT        2016
# 181680  181680           Audi                     A6 55 Premium        2020
# 17114    17114      Chevrolet                        Camaro 2SS        2016
# 182486  182486     Volkswagen  Golf R 4-Door w/DCC & Navigation        2018
# 45523    45523            BMW             M4 Competition xDrive        2023
#
#         milage fuel_type                                             engine  \
# 33636   140600  Gasoline      263.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 86166     1289  Gasoline      302.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 111314  171000  Gasoline       210.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 168952   47800  Gasoline      270.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 149629   39000  Gasoline       460.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 68511   103500  Gasoline      210.0HP 3.7L V6 Cylinder Engine Gasoline Fuel
# 134137    4700  Gasoline  502.0HP 4.0L Flat 6 Cylinder Engine Gasoline Fuel
# 31629    54259  Gasoline                               2.5L I4 16V GDI DOHC
# 3548     41906  Gasoline       445.0HP 4.4L 8 Cylinder Engine Gasoline Fuel
# 90029   168320  Gasoline       172.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# 96554    73500  Gasoline      450.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 76525    18603  Gasoline                         2.0L I4 16V GDI DOHC Turbo
# 85813    61341  Gasoline                         2.5L I4 16V GDI DOHC Turbo
# 148858  170000  Gasoline      268.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 182435   67500  Gasoline       430.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 188432   81000  Gasoline      365.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 181680   35580    Hybrid  335.0HP 3.0L V6 Cylinder Engine Gasoline/Mild ...
# 17114    91491  Gasoline       455.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 182486   23600  Gasoline       292.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 45523     3490  Gasoline  503.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
#
#                           transmission                  ext_col    int_col  \
# 33636                              A/T                    White      Beige
# 86166                      7-Speed A/T                     Gray     Silver
# 111314                     6-Speed M/T                    White      Black
# 168952                             A/T                     Blue       Gray
# 149629                    10-Speed A/T                     Blue      Black
# 68511                              A/T                   Orange       Gray
# 134137                     7-Speed A/T                     Gray      Black
# 31629                9-Speed Automatic  Ebony Twilight Metallic  Jet Black
# 3548                       8-Speed A/T                   Silver      White
# 90029                      6-Speed M/T                    White      Black
# 96554                     10-Speed A/T                    White      Black
# 76525                7-Speed Automatic                    Black      Black
# 85813                8-Speed Automatic   Deep Crystal Blue Mica      Black
# 148858                     6-Speed A/T                    Black      Black
# 182435  Transmission w/Dual Shift Mode                   Silver      Black
# 188432                     6-Speed A/T                    Black      Black
# 181680                             A/T                     Gray      Brown
# 17114                      6-Speed M/T                   Silver      Black
# 182486                     7-Speed A/T                    White        Red
# 45523                      8-Speed A/T                     Gray       Blue
#
#                                       accident clean_title   price
# 33636   At least 1 accident or damage reported         Yes   28500
# 86166                            None reported         Yes   69999
# 111314  At least 1 accident or damage reported         Yes   15900
# 168952  At least 1 accident or damage reported         Yes   24000
# 149629                           None reported         Yes   36000
# 68511                            None reported         Yes   14000
# 134137                           None reported         Yes  105000
# 31629                            None reported         Yes   39366
# 3548    At least 1 accident or damage reported         Yes   46900
# 90029   At least 1 accident or damage reported         Yes   14500
# 96554                            None reported         Yes   31450
# 76525                            None reported         Yes   42995
# 85813   At least 1 accident or damage reported         Yes   25987
# 148858                           None reported         Yes    2500
# 182435                           None reported         Yes   44800
# 188432                           None reported         Yes   18500
# 181680                           None reported         Yes   31500
# 17114                            None reported         Yes   15500
# 182486  At least 1 accident or damage reported         Yes   51950
# 45523                            None reported         Yes  130000

# %%
current_year = datetime.now().year
df['car_age'] = current_year - df['model_year'].astype(int)

# %%
luxury_brands = ['BMW', 'Mercedes-Benz', 'Audi', 'Tesla', 'Porsche', 'Land', 'Aston', 'Lexus', 'Lincoln', 'Lamborghini', 'Bugatti', 'Cadillac', 'Maserati', 'Genesis', ' Acura']
df['Luxurious'] = df['brand'].apply(lambda x: 'Yes' if x in luxury_brands else 'No')

# %%
label_encoder = LabelEncoder()
df['brand'] = label_encoder.fit_transform(df['brand'])
df['fuel_type'] = label_encoder.fit_transform(df['fuel_type'])
df['transmission'] = label_encoder.fit_transform(df['transmission'])
df['ext_col'] = label_encoder.fit_transform(df['ext_col'])
df['int_col'] = label_encoder.fit_transform(df['int_col'])
df['accident'] = label_encoder.fit_transform(df['accident'])
df['clean_title'] = label_encoder.fit_transform(df['clean_title'])
df['Luxurious'] = label_encoder.fit_transform(df['Luxurious'])

# %%
def extract_engine_features(engine_desc):
    hp_match = re.search(r'(\d+(\.\d+)?)HP', engine_desc)
    hp = float(hp_match.group(1)) if hp_match else None

    l_match = re.search(r'(\d+(\.\d+)?)L', engine_desc)
    displacement = float(l_match.group(1)) if l_match else None

    cyl_match = re.search(r'(\d+) Cylinder', engine_desc)
    cylinders = int(cyl_match.group(1)) if cyl_match else None

    turbocharged = 1 if 'Turbo' in engine_desc else 0

    return hp, displacement, cylinders, turbocharged

df[['HP', 'Liters', 'Cylinders', 'Turbocharged']] = df['engine'].apply(
    lambda x: pd.Series(extract_engine_features(x))
)
drop_columns = ['engine', 'model']
df.drop(drop_columns, axis=1, inplace=True)

df.fillna(df.mean(), inplace=True)

df.sample(15)
# Out:
#             id  brand  model_year  milage  fuel_type  transmission  ext_col  \
# 44156    44156     38        2016   75000          2            41       28
# 169836  169836     14        2018   67650          2            38      257
# 150792  150792     27        2023    8800          2            49      126
# 124341  124341     36        2017   38383          2            23      257
# 33682    33682      9        2003  107750          2            38       28
# 135476  135476     55        2019   59271          2            38       37
# 108055  108055     14        2022   11875          2             3      270
# 158843  158843     17        2016   79000          2            38      298
# 79468    79468      4        2016   80134          2            31       28
# 57188    57188     50        2014   71273          2            20      229
# 68145    68145     14        2020   13000          2            16      298
# 163123  163123     22        2017   89563          2            38       28
# 167546  167546      0        2021   69185          2            36       93
# 52773    52773     14        2022    2500          2            44      126
# 128982  128982     34        2005  111300          2            16       37
#
#         int_col  accident  clean_title   price  car_age  Luxurious  \
# 44156        14         0            0   17500        8          0
# 169836       14         1            0  103000        6          0
# 150792       14         1            0  128900        1          1
# 124341       14         1            0   21499        7          1
# 33682        71         1            0   15000       21          0
# 135476      152         1            0   25000        5          0
# 108055       21         0            0   29999        2          0
# 158843       14         1            0   19000        8          0
# 79468        10         1            0   36800        8          1
# 57188        14         1            0   25099       10          0
# 68145        14         1            0   26000        4          0
# 163123       14         1            0   24900        7          0
# 167546      110         1            0   39951        3          0
# 52773        14         1            0   94000        2          0
# 128982       71         0            0    7200       19          0
#
#                 HP  Liters  Cylinders  Turbocharged
# 44156   166.000000     2.4   4.000000           0.0
# 169836  365.000000     3.5   6.000000           0.0
# 150792  383.000000     5.7   8.000000           0.0
# 124341  469.000000     4.0   8.000000           0.0
# 33682   240.000000     3.8   6.000000           0.0
# 135476  330.000000     2.0   4.000000           0.0
# 108055  338.336712     3.5   6.373096           1.0
# 158843  252.000000     2.0   4.000000           0.0
# 79468   320.000000     3.0   6.000000           0.0
# 57188   268.000000     2.0   4.000000           0.0
# 68145   310.000000     3.5   6.000000           0.0
# 163123  180.000000     2.4   4.000000           0.0
# 167546  338.336712     2.0   6.373096           1.0
# 52773   526.000000     5.2   8.000000           0.0
# 128982  244.000000     2.3   4.000000           0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 162610 entries, 0 to 188532
# Data columns (total 17 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            162610 non-null  int64
#  1   brand         162610 non-null  int64
#  2   model_year    162610 non-null  int64
#  3   milage        162610 non-null  int64
#  4   fuel_type     162610 non-null  int64
#  5   transmission  162610 non-null  int64
#  6   ext_col       162610 non-null  int64
#  7   int_col       162610 non-null  int64
#  8   accident      162610 non-null  int64
#  9   clean_title   162610 non-null  int64
#  10  price         162610 non-null  int64
#  11  car_age       162610 non-null  int64
#  12  Luxurious     162610 non-null  int64
#  13  HP            162610 non-null  float64
#  14  Liters        162610 non-null  float64
#  15  Cylinders     162610 non-null  float64
#  16  Turbocharged  162610 non-null  float64
# dtypes: float64(4), int64(13)
# memory usage: 22.3 MB

# %%
X = df.drop(['price'],axis=1)
y = df['price']
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.4,random_state=46)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
mean_squared_error(y_test, y_pred, squared=False)
# Out:
# 68355.7732177658

# %% [markdown]
# ## Test File

# %%
test_url = 'https://github.com/robitussin/CCMACLRL_EXAM/blob/a46a4e2a001dedaefc9b431d480b508ce86c2d96/datasets/test.csv?raw=true'
dt=pd.read_csv(test_url)

# %%
dt.head()
# Out:
#        id brand                 model  model_year  milage fuel_type  \
# 0  188533  Land        Rover LR2 Base        2015   98000  Gasoline
# 1  188534  Land     Rover Defender SE        2020    9142    Hybrid
# 2  188535  Ford    Expedition Limited        2022   28121  Gasoline
# 3  188536  Audi         A6 2.0T Sport        2016   61258  Gasoline
# 4  188537  Audi  A6 2.0T Premium Plus        2018   59000  Gasoline
#
#                                               engine        transmission  \
# 0       240.0HP 2.0L 4 Cylinder Engine Gasoline Fuel         6-Speed A/T
# 1  395.0HP 3.0L Straight 6 Cylinder Engine Gasoli...         8-Speed A/T
# 2                    3.5L V6 24V PDI DOHC Twin Turbo  10-Speed Automatic
# 3                                     2.0 Liter TFSI           Automatic
# 4       252.0HP 2.0L 4 Cylinder Engine Gasoline Fuel                 A/T
#
#            ext_col int_col       accident clean_title
# 0            White   Beige  None reported         Yes
# 1           Silver   Black  None reported         Yes
# 2            White   Ebony  None reported         NaN
# 3  Silician Yellow   Black  None reported         NaN
# 4             Gray   Black  None reported         Yes

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125690 entries, 0 to 125689
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            125690 non-null  int64
#  1   brand         125690 non-null  object
#  2   model         125690 non-null  object
#  3   model_year    125690 non-null  int64
#  4   milage        125690 non-null  int64
#  5   fuel_type     122307 non-null  object
#  6   engine        125690 non-null  object
#  7   transmission  125690 non-null  object
#  8   ext_col       125690 non-null  object
#  9   int_col       125690 non-null  object
#  10  accident      124058 non-null  object
#  11  clean_title   111451 non-null  object
# dtypes: int64(3), object(9)
# memory usage: 11.5+ MB

# %%
dt.isnull().sum()
# Out:
# id                  0
# brand               0
# model               0
# model_year          0
# milage              0
# fuel_type        3383
# engine              0
# transmission        0
# ext_col             0
# int_col             0
# accident         1632
# clean_title     14239
# dtype: int64

# %%
dt.describe()
# Out:
#                   id     model_year         milage
# count  125690.000000  125690.000000  125690.000000
# mean   251377.500000    2015.797526   66042.581510
# std     36283.722005       5.673797   50223.858435
# min    188533.000000    1974.000000     100.000000
# 25%    219955.250000    2013.000000   24500.000000
# 50%    251377.500000    2017.000000   57500.000000
# 75%    282799.750000    2020.000000   95798.000000
# max    314222.000000    2024.000000  405000.000000

# %%
dt.sample(20)
# Out:
#             id      brand                                model  model_year  \
# 87412   275945     Jaguar                           XF Premium        2013
# 68997   257530      Acura                       MDX Technology        2007
# 99226   287759       Ford                  E350 Super Duty XLT        2011
# 36953   225486      Dodge                          Durango SRT        2020
# 26764   215297     Toyota                     Camry Hybrid XLE        2015
# 10187   198720     Subaru                         WRX STI Base        2014
# 83519   272052       Ford                         F-150 Raptor        2023
# 116308  304841    Porsche                          Panamera 4S        2015
# 59344   247877   Cadillac              Escalade Premium Luxury        2021
# 112513  301046    Genesis                            GV70 2.5T        2022
# 89472   278005        BMW                M4 Competition xDrive        2021
# 112885  301418       Land  Rover Range Rover Evoque SE Premium        2021
# 60136   248669    McLaren                            570S Base        2017
# 16542   205075  Chevrolet              Corvette Stingray w/2LT        2019
# 56723   245256     Subaru                 Legacy 2.5 i Premium        2008
# 55418   243951     Toyota                     Camry Solara SLE        2004
# 48687   237220     Nissan                          Frontier SV        2013
# 5383    193916       Audi                               R8 5.2        2010
# 14433   202966  Chevrolet              Corvette Stingray w/3LT        2022
# 116798  305331       Ford                  Expedition Platinum        2020
#
#         milage      fuel_type  \
# 87412   106000       Gasoline
# 68997   137200       Gasoline
# 99226   158000  E85 Flex Fuel
# 36953    31804       Gasoline
# 26764    96419         Hybrid
# 10187    71400       Gasoline
# 83519     3490         Hybrid
# 116308   38718       Gasoline
# 59344    23600       Gasoline
# 112513   20319       Gasoline
# 89472    16554       Gasoline
# 112885   48500       Gasoline
# 60136     7858       Gasoline
# 16542     8228       Gasoline
# 56723   162000       Gasoline
# 55418   152000       Gasoline
# 48687   103400       Gasoline
# 5383      9400       Gasoline
# 14433    12000       Gasoline
# 116798   83298       Gasoline
#
#                                                    engine  \
# 87412        385.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 68997       300.0HP 3.7L V6 Cylinder Engine Gasoline Fuel
# 99226   255.0HP 5.4L 8 Cylinder Engine Flex Fuel Capab...
# 36953        475.0HP 6.4L 8 Cylinder Engine Gasoline Fuel
# 26764   200.0HP 2.5L 4 Cylinder Engine Gas/Electric Hy...
# 10187        268.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 83519       450.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 116308       440.0HP 4.7L 8 Cylinder Engine Gasoline Fuel
# 59344        420.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 112513       300.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 89472   503.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 112885       237.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 60136        562.0HP 3.8L 8 Cylinder Engine Gasoline Fuel
# 16542        490.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 56723        170.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 55418       210.0HP 3.3L V6 Cylinder Engine Gasoline Fuel
# 48687       261.0HP 4.0L V6 Cylinder Engine Gasoline Fuel
# 5383        550.0HP 5.2L 10 Cylinder Engine Gasoline Fuel
# 14433        490.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 116798                                     3.5 Liter GTDI
#
#                           transmission ext_col int_col  \
# 87412                      6-Speed A/T    Gold   Brown
# 68997                      6-Speed A/T  Silver   Black
# 99226                              A/T    Blue   Beige
# 36953                      8-Speed A/T    Gray   Black
# 26764                              A/T   Black   Black
# 10187                      6-Speed M/T   Green   Black
# 83519                     10-Speed A/T   Black   Black
# 116308  Transmission w/Dual Shift Mode    Gray   Beige
# 59344                              A/T   White   Brown
# 112513                     8-Speed A/T    Gray   Beige
# 89472                              A/T    Blue    Gray
# 112885  Transmission w/Dual Shift Mode    Gray   Black
# 60136   Transmission w/Dual Shift Mode   White   Black
# 16542   Transmission w/Dual Shift Mode   White     Red
# 56723                              A/T  Silver   Black
# 55418                      5-Speed A/T   Black    Gray
# 48687                      5-Speed A/T   White    Gray
# 5383                       8-Speed A/T   Black   Black
# 14433   Transmission w/Dual Shift Mode   Black   Black
# 116798                       Automatic   White  Ebony.
#
#                                       accident clean_title
# 87412   At least 1 accident or damage reported         Yes
# 68997                            None reported         Yes
# 99226                            None reported         Yes
# 36953                            None reported         Yes
# 26764   At least 1 accident or damage reported         Yes
# 10187                            None reported         Yes
# 83519                            None reported         Yes
# 116308                           None reported         Yes
# 59344   At least 1 accident or damage reported         Yes
# 112513                           None reported         Yes
# 89472                            None reported         Yes
# 112885                           None reported         Yes
# 60136   At least 1 accident or damage reported         Yes
# 16542                            None reported         Yes
# 56723                            None reported         Yes
# 55418   At least 1 accident or damage reported         Yes
# 48687   At least 1 accident or damage reported         Yes
# 5383                             None reported         Yes
# 14433                            None reported         Yes
# 116798                           None reported         NaN

# %%
current_year = datetime.now().year
dt['car_age'] = current_year - df['model_year'].astype(int)

# %%
luxury_brands = ['BMW', 'Mercedes-Benz', 'Audi', 'Tesla', 'Porsche', 'Land', 'Aston', 'Lexus', 'Lincoln', 'Lamborghini', 'Bugatti', 'Cadillac', 'Maserati', 'Genesis', ' Acura']
dt['Luxurious'] = df['brand'].apply(lambda x: 'Yes' if x in luxury_brands else 'No')

# %%
label_encoder = LabelEncoder()
dt['brand'] = label_encoder.fit_transform(dt['brand'])
dt['fuel_type'] = label_encoder.fit_transform(dt['fuel_type'])
dt['transmission'] = label_encoder.fit_transform(dt['transmission'])
dt['ext_col'] = label_encoder.fit_transform(dt['ext_col'])
dt['int_col'] = label_encoder.fit_transform(dt['int_col'])
dt['accident'] = label_encoder.fit_transform(dt['accident'])
dt['clean_title'] = label_encoder.fit_transform(dt['clean_title'])
dt['Luxurious'] = label_encoder.fit_transform(dt['Luxurious'])

# %%
# Function to extract engine features
def extract_engine_features(engine_desc):
    # Extract horsepower (HP)
    hp_match = re.search(r'(\d+(\.\d+)?)HP', engine_desc)
    hp = float(hp_match.group(1)) if hp_match else None

    # Extract engine displacement (L)
    l_match = re.search(r'(\d+(\.\d+)?)L', engine_desc)
    displacement = float(l_match.group(1)) if l_match else None

    # Extract cylinder count
    cyl_match = re.search(r'(\d+) Cylinder', engine_desc)
    cylinders = int(cyl_match.group(1)) if cyl_match else None

    # Check if turbocharged
    turbocharged = 1 if 'Turbo' in engine_desc else 0

    return hp, displacement, cylinders, turbocharged

dt[['HP', 'Liters', 'Cylinders', 'Turbocharged']] = dt['engine'].apply(
    lambda x: pd.Series(extract_engine_features(x))
)
drop_columns = ['engine', 'model']
dt.drop(drop_columns, axis=1, inplace=True)

dt.fillna(dt.mean(), inplace=True)

dt.sample(15)
# Out:
#             id  brand  model_year  milage  fuel_type  transmission  ext_col  \
# 12905   201438     14        2021   15600          2             2       29
# 3637    192170     14        2022   56778          2             2      127
# 106436  294969      1        2017   23230          2            31       29
# 44044   232577     22        2018   71312          2            38       38
# 13407   201940     39        2012   51700          2            38       29
# 89842   278375     45        2021   18160          2            32      127
# 20816   209349     31        2009  110022          2            20      127
# 116665  305198      8        2021   28121          0             3       29
# 43154   231687      9        2020   71536          2             3       29
# 783     189316      8        2021    4100          2            49      302
# 19842   208375     14        2003  229450          0            38      121
# 80827   269360     27        2012  153250          2            38       29
# 9631    198164      9        2018   65441          2            16      127
# 102341  290874     42        2022   10654          2            39       29
# 1541    190074     42        2016   87500          2            31      302
#
#         int_col  accident  clean_title   car_age  Luxurious          HP  \
# 12905        14         1            0   3.00000          0  315.000000
# 3637         14         1            0   2.00000          0  315.000000
# 106436      155         1            0   9.00000          0  280.000000
# 44044        14         1            0   8.85398          1  180.000000
# 13407        71         2            1   1.00000          0  375.000000
# 89842        14         1            0   8.85398          1  342.797283
# 20816        14         1            0   8.00000          0  172.000000
# 116665       79         1            1   4.00000          0  342.797283
# 43154        14         1            0  19.00000          0  342.797283
# 783          14         1            0  20.00000          0  420.000000
# 19842        10         1            0  12.00000          0  325.000000
# 80827        14         1            0   6.00000          0  380.000000
# 9631         14         1            0  10.00000          0  355.000000
# 102341       14         1            1   5.00000          0  342.797283
# 1541         14         0            0   6.00000          0  300.000000
#
#           Liters  Cylinders  Turbocharged
# 12905   2.700000   6.000000           0.0
# 3637    2.700000   6.000000           0.0
# 106436  2.000000   4.000000           0.0
# 44044   2.400000   4.000000           0.0
# 13407   5.600000   8.000000           0.0
# 89842   6.700000   6.372479           1.0
# 20816   1.600000   4.000000           0.0
# 116665  3.000000   6.372479           1.0
# 43154   5.300000   6.372479           0.0
# 783     6.200000   8.000000           0.0
# 19842   6.000000   8.000000           0.0
# 80827   4.600000   8.000000           0.0
# 9631    5.300000   8.000000           0.0
# 102341  3.801503   6.372479           0.0
# 1541    3.600000   6.000000           0.0

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125690 entries, 0 to 125689
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            125690 non-null  int64
#  1   brand         125690 non-null  int64
#  2   model_year    125690 non-null  int64
#  3   milage        125690 non-null  int64
#  4   fuel_type     125690 non-null  int64
#  5   transmission  125690 non-null  int64
#  6   ext_col       125690 non-null  int64
#  7   int_col       125690 non-null  int64
#  8   accident      125690 non-null  int64
#  9   clean_title   125690 non-null  int64
#  10  car_age       125690 non-null  float64
#  11  Luxurious     125690 non-null  int64
#  12  HP            125690 non-null  float64
#  13  Liters        125690 non-null  float64
#  14  Cylinders     125690 non-null  float64
#  15  Turbocharged  125690 non-null  float64
# dtypes: float64(5), int64(11)
# memory usage: 15.3 MB

# %% [markdown]
# ## Sample Submission File

# %%
sample_submission_url = 'https://github.com/robitussin/CCMACLRL_EXAM/blob/a46a4e2a001dedaefc9b431d480b508ce86c2d96/datasets/sample_submission.csv?raw=true'

sf=pd.read_csv(sample_submission_url)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 162610 entries, 0 to 188532
# Data columns (total 17 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            162610 non-null  int64
#  1   brand         162610 non-null  int64
#  2   model_year    162610 non-null  int64
#  3   milage        162610 non-null  int64
#  4   fuel_type     162610 non-null  int64
#  5   transmission  162610 non-null  int64
#  6   ext_col       162610 non-null  int64
#  7   int_col       162610 non-null  int64
#  8   accident      162610 non-null  int64
#  9   clean_title   162610 non-null  int64
#  10  price         162610 non-null  int64
#  11  car_age       162610 non-null  int64
#  12  Luxurious     162610 non-null  int64
#  13  HP            162610 non-null  float64
#  14  Liters        162610 non-null  float64
#  15  Cylinders     162610 non-null  float64
#  16  Turbocharged  162610 non-null  float64
# dtypes: float64(4), int64(13)
# memory usage: 26.4 MB

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125690 entries, 0 to 125689
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            125690 non-null  int64
#  1   brand         125690 non-null  int64
#  2   model_year    125690 non-null  int64
#  3   milage        125690 non-null  int64
#  4   fuel_type     125690 non-null  int64
#  5   transmission  125690 non-null  int64
#  6   ext_col       125690 non-null  int64
#  7   int_col       125690 non-null  int64
#  8   accident      125690 non-null  int64
#  9   clean_title   125690 non-null  int64
#  10  car_age       125690 non-null  float64
#  11  Luxurious     125690 non-null  int64
#  12  HP            125690 non-null  float64
#  13  Liters        125690 non-null  float64
#  14  Cylinders     125690 non-null  float64
#  15  Turbocharged  125690 non-null  float64
# dtypes: float64(5), int64(11)
# memory usage: 15.3 MB

# %%
id = sf.pop('id')
y_pred = model.predict(dt)

# Create a submission DataFrame
submission_df = pd.DataFrame({
    'id': id,
    'class': y_pred
})

# Save the submission DataFrame to a CSV file
submission_df.to_csv('results.csv', index=False)
print("Submission file created: submission_file.csv")
# Out:
# Submission file created: submission_file.csv
